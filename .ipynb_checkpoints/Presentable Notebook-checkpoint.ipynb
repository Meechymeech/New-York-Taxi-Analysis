# %% [markdown]
# # __New York Taxi Driver Analysis__
#
# ##### Problem Definition: Predict the average income of a taxi driver in NYC. Done by hour and by region.

# %% [markdown]
# ##### This is a guided project by [Misra Turp](#https://www.youtube.com/playlist?list=PLM8lYG2MzHmTgsYKLJtdKwf6tHVbui9eE) in combination with the information learned in the IBM Data Science Professional Certification course.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Import Dataset

# %%
taxi_jan_2025 = pd.read_parquet('data/yellow_tripdata_2025-01.parquet')

## Concatenating data sets to allow later months to be added in the future.
taxi_data = pd.concat([taxi_jan_2025])

# %%
taxi_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.60         1.0                  N           229           237
# 1           0.50         1.0                  N           236           237
# 2           0.60         1.0                  N           141           141
# 3           0.52         1.0                  N           244           244
# 4           0.66         1.0                  N           244           116
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         10.0    3.5      0.5        3.00           0.0
# 1             1          5.1    3.5      0.5        2.02           0.0
# 2             1          5.1    3.5      0.5        2.00           0.0
# 3             2          7.2    1.0      0.5        0.00           0.0
# 4             2          5.8    1.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         18.00                   2.5          0.0
# 1                    1.0         12.12                   2.5          0.0
# 2                    1.0         12.10                   2.5          0.0
# 3                    1.0          9.70                   0.0          0.0
# 4                    1.0          8.30                   0.0          0.0

# %%
taxi_data.shape
# Out:
# (3475226, 19)

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 2.1 - Dropping Unnecessary Columns

# %%
taxi_data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
## Removing unnecessary columns
taxi_data = taxi_data.drop(columns=['store_and_fwd_flag','fare_amount','extra','mta_tax','tip_amount','tolls_amount',
                                    'improvement_surcharge','congestion_surcharge','Airport_fee'])

# %%
taxi_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           1.60         1.0           229           237             1
# 1           0.50         1.0           236           237             1
# 2           0.60         1.0           141           141             1
# 3           0.52         1.0           244           244             2
# 4           0.66         1.0           244           116             2
#
#    total_amount
# 0         18.00
# 1         12.12
# 2         12.10
# 3          9.70
# 4          8.30

# %% [markdown]
# ### 2.2 - Visualizing Data to Spot Abnormalities

# %%
## Plotting using the Historgram
taxi_data.hist(figsize=(20,10), bins=60, color='pink')
# Out:
# array([[<Axes: title={'center': 'VendorID'}>,
#         <Axes: title={'center': 'tpep_pickup_datetime'}>,
#         <Axes: title={'center': 'tpep_dropoff_datetime'}>],
#        [<Axes: title={'center': 'passenger_count'}>,
#         <Axes: title={'center': 'trip_distance'}>,
#         <Axes: title={'center': 'RatecodeID'}>],
#        [<Axes: title={'center': 'PULocationID'}>,
#         <Axes: title={'center': 'DOLocationID'}>,
#         <Axes: title={'center': 'payment_type'}>],
#        [<Axes: title={'center': 'total_amount'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
taxi_data['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1.0     2756472
# 2.0       94420
# 99.0      41963
# 5.0       26501
# 3.0        8622
# 4.0        7092
# 6.0           7
# Name: count, dtype: int64

# %%
taxi_data.reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(10,5), color='pink')
plt.title("Total Amounts")
plt.show()

# %%
taxi_data[taxi_data['total_amount']<1000].reset_index().plot(kind='scatter', color='pink', y='total_amount', x='index', figsize=(10,5))
plt.title("Total Amounts -  Less than $1,000")
plt.show()

# %%
## Printing the negative values 
print(taxi_data[taxi_data['total_amount']<0].shape)
# Out:
# (63037, 10)

# %%
taxi_data[taxi_data['total_amount']<0].reset_index().plot(kind='scatter', color='pink', y='total_amount', x='index', figsize=(10,5))
plt.title("Negative Total Amounts")
plt.show()

# %%
taxi_data[taxi_data['total_amount']<0].head(10)
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 17          2  2025-01-01 00:01:41   2025-01-01 00:07:14              1.0
# 22          2  2025-01-01 00:55:54   2025-01-01 01:00:38              1.0
# 104         2  2025-01-01 00:56:12   2025-01-01 01:15:00              1.0
# 149         2  2025-01-01 00:55:53   2025-01-01 01:06:49              1.0
# 202         2  2025-01-01 00:29:35   2025-01-01 00:36:02              1.0
# 212         2  2025-01-01 00:11:44   2025-01-01 00:25:41              2.0
# 364         2  2025-01-01 00:11:58   2025-01-01 00:12:31              1.0
# 400         2  2025-01-01 00:09:58   2025-01-01 00:14:28              1.0
# 492         2  2025-01-01 00:50:13   2025-01-01 01:11:20              1.0
# 640         2  2025-01-01 00:51:05   2025-01-01 00:54:12              1.0
#
#      trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 17            0.71         1.0            79           107             2
# 22            0.69         1.0           137           233             4
# 104           0.97         1.0           161           170             4
# 149           1.42         1.0            79            45             2
# 202           0.60         1.0            79           148             4
# 212           1.88         1.0            79           161             4
# 364           0.01         1.0            42            42             4
# 400           0.60         1.0           140           263             2
# 492           3.84         1.0            48           151             2
# 640           0.92         1.0           142           239             2
#
#      total_amount
# 17          -8.54
# 22         -11.50
# 104        -21.30
# 149        -17.10
# 202        -12.20
# 212        -19.20
# 364         -5.50
# 400        -11.50
# 492        -29.00
# 640        -11.50

# %%
taxi_data[taxi_data['total_amount']<0]['payment_type'].value_counts()
# Out:
# payment_type
# 4    37410
# 2    14111
# 3     8080
# 0     3421
# 1       15
# Name: count, dtype: int64

# %%
taxi_data[taxi_data['total_amount']<0]['trip_distance'].hist(bins=60, figsize=(10,5), color='pink')
plt.title("Trip Distance")
plt.show()

# %%
print(taxi_data[taxi_data['total_amount']==0].shape)
taxi_data[taxi_data['total_amount']==0].head()
# Out:
# (559, 10)
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 10261         2  2025-01-01 01:30:13   2025-01-01 01:30:31              1.0
# 18189         1  2025-01-01 03:57:21   2025-01-01 04:02:26              1.0
# 19155         1  2025-01-01 03:27:25   2025-01-01 03:43:43              1.0
# 21300         2  2025-01-01 04:03:25   2025-01-01 04:11:42              2.0
# 21920         2  2025-01-01 04:24:55   2025-01-01 04:29:57              4.0
#
#        trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 10261           0.00         1.0           226           226             2
# 18189           0.40         1.0           158           125             3
# 19155           3.50         1.0           144           163             4
# 21300           4.69         1.0           255            97             2
# 21920           1.72         1.0             7             7             2
#
#        total_amount
# 10261           0.0
# 18189           0.0
# 19155           0.0
# 21300           0.0
# 21920           0.0

# %%
taxi_data[taxi_data['total_amount']==0]['payment_type'].value_counts()
# Out:
# payment_type
# 4    238
# 3    155
# 1     78
# 0     47
# 2     40
# 5      1
# Name: count, dtype: int64

# %%
taxi_data[taxi_data['total_amount']==0]['trip_distance'].hist(bins=60, figsize=(10,5), color='pink')
plt.title("Trip Distance with total amount at 0")
plt.show()

# %%
taxi_data[taxi_data['total_amount']==0]['trip_distance'].value_counts()
# Out:
# trip_distance
# 0.00     262
# 0.10      19
# 0.50      17
# 0.40      15
# 0.30      14
#         ...
# 1.46       1
# 6.60       1
# 1.72       1
# 1.45       1
# 14.68      1
# Name: count, Length: 112, dtype: int64

# %%
taxi_data.reset_index().plot(kind='scatter', color='pink', y='total_amount', x='index', figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_data[taxi_data['total_amount']>200].shape
# Out:
# (1913, 10)

# %%
taxi_data['total_amount'].mean()
# Out:
# 25.61129169728817

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ### 3.1 - Handling Invalid Fare Amounts (Negative and Extremely Large Values)

# %%
taxi_data_filtered = taxi_data[(taxi_data['total_amount']>=0)&(taxi_data['total_amount']<200)]

# %%
print(taxi_data.shape)
taxi_data_filtered.shape
# Out:
# (3475226, 10)
# (3410271, 10)

# %%
taxi_data_filtered.isna().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          536722
# trip_distance                 0
# RatecodeID               536722
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# total_amount                  0
# dtype: int64

# %% [markdown]
# ### 3.2 - Investigating Missing or Suspicious Values (Passenger Count & RatecodeID)

# %%
taxi_data_filtered[taxi_data_filtered['passenger_count']==0].shape
# Out:
# (24639, 10)

# %%
taxi_data_filtered[taxi_data_filtered['passenger_count'].isna()].head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2935077         2  2025-01-01 00:39:17   2025-01-01 01:10:42              NaN
# 2935078         2  2025-01-01 00:33:40   2025-01-01 01:10:34              NaN
# 2935079         1  2025-01-01 00:09:32   2025-01-01 00:12:38              NaN
# 2935080         2  2025-01-01 00:21:42   2025-01-01 00:36:29              NaN
# 2935081         2  2025-01-01 00:56:04   2025-01-01 01:06:11              NaN
#
#          trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 2935077           6.75         NaN            48            42             0
# 2935078           3.88         NaN             4            48             0
# 2935079           0.00         NaN           158           158             0
# 2935080           3.55         NaN           137           211             0
# 2935081           1.55         NaN           140           233             0
#
#          total_amount
# 2935077         14.90
# 2935078         10.02
# 2935079         26.72
# 2935080          5.80
# 2935081          9.06

# %%
taxi_data_filtered[taxi_data_filtered['passenger_count']==0].head()
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6          1  2025-01-01 00:14:47   2025-01-01 00:16:15              0.0
# 7          1  2025-01-01 00:39:27   2025-01-01 00:51:51              0.0
# 8          1  2025-01-01 00:53:43   2025-01-01 01:13:23              0.0
# 94         1  2025-01-01 00:11:27   2025-01-01 00:16:58              0.0
# 95         1  2025-01-01 00:19:30   2025-01-01 00:27:25              0.0
#
#     trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 6             0.4         1.0           170           170             1
# 7             1.6         1.0           234           148             1
# 8             2.8         1.0           148           170             1
# 94            0.7         1.0           144           211             1
# 95            1.0         1.0           211           158             1
#
#     total_amount
# 6          11.75
# 7          19.10
# 8          27.10
# 94         12.20
# 95         17.15

# %%
## Removing the null values 
taxi_data_filtered = taxi_data_filtered.dropna(subset=['passenger_count'])
taxi_data_filtered.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# total_amount             0
# dtype: int64

# %% [markdown]
# ## 4. Data Preparation

# %% [markdown]
# ### 4.1 - Copying Dataset for Preparation

# %%
# Coping the filtered data frame 
taxi_data_prepared = taxi_data_filtered.copy()

# %%
# Checking all data types
taxi_data_prepared.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# total_amount                    float64
# dtype: object

# %%
# Checking if there are any decimal values in passenger_type
(taxi_data_prepared['passenger_count'] % 1 != 0).sum()
# Out:
# 0

# %% [markdown]
# ### 4.2 - Converting Variables to Appropriate Data Types

# %%
taxi_data_prepared['RatecodeID']      = taxi_data_prepared['RatecodeID'].astype(str)
taxi_data_prepared['PULocationID']    = taxi_data_prepared['PULocationID'].astype(str)
taxi_data_prepared['DOLocationID']    = taxi_data_prepared['DOLocationID'].astype(str)
taxi_data_prepared['payment_type']    = taxi_data_prepared['payment_type'].astype(str)
taxi_data_prepared['passenger_count'] = taxi_data_prepared['passenger_count'].astype(int)

# %%
taxi_data_prepared.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                   int32
# trip_distance                   float64
# RatecodeID                       object
# PULocationID                     object
# DOLocationID                     object
# payment_type                     object
# total_amount                    float64
# dtype: object

# %%
taxi_data_prepared.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59                1
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13                1
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01                1
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01                3
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06                3
#
#    trip_distance RatecodeID PULocationID DOLocationID payment_type  \
# 0           1.60        1.0          229          237            1
# 1           0.50        1.0          236          237            1
# 2           0.60        1.0          141          141            1
# 3           0.52        1.0          244          244            2
# 4           0.66        1.0          244          116            2
#
#    total_amount
# 0         18.00
# 1         12.12
# 2         12.10
# 3          9.70
# 4          8.30

# %% [markdown]
# ### 4.3 - Extracting Data and Time for Income Analysis

# %%
taxi_data_prepared['transaction_date']  = pd.to_datetime(taxi_data_prepared['tpep_pickup_datetime'].dt.date)
taxi_data_prepared['transaction_year']  = taxi_data_prepared['tpep_pickup_datetime'].dt.year
taxi_data_prepared['transaction_month'] = taxi_data_prepared['tpep_pickup_datetime'].dt.month
taxi_data_prepared['transaction_day']   = taxi_data_prepared['tpep_pickup_datetime'].dt.day
taxi_data_prepared['transaction_hour']  = taxi_data_prepared['tpep_pickup_datetime'].dt.hour

# %%
taxi_data_prepared.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2025-01-01 00:18:38   2025-01-01 00:26:59                1
# 1         1  2025-01-01 00:32:40   2025-01-01 00:35:13                1
# 2         1  2025-01-01 00:44:04   2025-01-01 00:46:01                1
# 3         2  2025-01-01 00:14:27   2025-01-01 00:20:01                3
# 4         2  2025-01-01 00:21:34   2025-01-01 00:25:06                3
#
#    trip_distance RatecodeID PULocationID DOLocationID payment_type  \
# 0           1.60        1.0          229          237            1
# 1           0.50        1.0          236          237            1
# 2           0.60        1.0          141          141            1
# 3           0.52        1.0          244          244            2
# 4           0.66        1.0          244          116            2
#
#    total_amount transaction_date  transaction_year  transaction_month  \
# 0         18.00       2025-01-01              2025                  1
# 1         12.12       2025-01-01              2025                  1
# 2         12.10       2025-01-01              2025                  1
# 3          9.70       2025-01-01              2025                  1
# 4          8.30       2025-01-01              2025                  1
#
#    transaction_day  transaction_hour
# 0                1                 0
# 1                1                 0
# 2                1                 0
# 3                1                 0
# 4                1                 0

# %%
(taxi_data_prepared['transaction_year']!=2025).sum()
# Out:
# 21

# %%
taxi_data_prepared[taxi_data_prepared['transaction_year']!=2025].head(21)
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 605           2  2024-12-31 23:30:03   2024-12-31 23:43:02                1
# 687           2  2024-12-31 23:31:38   2024-12-31 23:41:48                1
# 688           2  2024-12-31 23:46:38   2025-01-01 00:03:03                1
# 861           2  2024-12-31 23:56:19   2025-01-01 00:11:19                6
# 1108          2  2024-12-31 23:55:37   2025-01-01 00:01:26                1
# 1312          2  2024-12-31 23:52:40   2025-01-01 00:23:03                1
# 2276          2  2024-12-31 23:49:24   2024-12-31 23:57:30                1
# 3941          2  2024-12-31 23:27:13   2024-12-31 23:35:48                1
# 3942          2  2024-12-31 23:37:42   2024-12-31 23:43:10                1
# 4324          2  2024-12-31 23:51:20   2025-01-01 00:00:00                1
# 4370          2  2024-12-31 23:53:51   2025-01-01 00:16:32                1
# 4654          2  2024-12-31 23:24:31   2024-12-31 23:25:35                5
# 4655          2  2024-12-31 23:25:38   2025-01-01 01:01:53                5
# 5217          2  2024-12-31 23:48:48   2024-12-31 23:55:13                1
# 5335          2  2024-12-31 23:48:29   2025-01-01 00:04:04                1
# 7623          2  2024-12-31 20:47:55   2024-12-31 20:54:00                2
# 7624          2  2024-12-31 20:54:50   2024-12-31 21:30:18                2
# 7625          2  2024-12-31 21:20:05   2024-12-31 21:35:13                2
# 17542         2  2024-12-31 20:52:50   2024-12-31 21:09:34                2
# 20611         2  2024-12-31 21:15:22   2024-12-31 21:26:00                2
# 20612         2  2024-12-31 21:33:43   2024-12-31 21:39:00                2
#
#        trip_distance RatecodeID PULocationID DOLocationID payment_type  \
# 605             3.00        1.0          246           13            1
# 687             1.03        1.0           43          140            2
# 688             3.95        1.0          229           24            2
# 861             2.28        1.0           68          107            1
# 1108            1.12        1.0           56           56            2
# 1312            6.72        1.0          114          151            1
# 2276            2.44        1.0          142          151            1
# 3941            1.53        1.0          170          141            1
# 3942            0.92        1.0          229          141            1
# 4324           12.89        1.0          138           40            1
# 4370            3.23        1.0          163           79            1
# 4654            0.28        1.0          132          132            2
# 4655           18.78        2.0          132          142            1
# 5217            0.99        1.0          114          148            1
# 5335            2.53        1.0          186           79            2
# 7623            1.72        1.0           48          246            1
# 7624            1.39        1.0          246           48            1
# 7625            2.64        1.0           42          238            1
# 17542           5.05        1.0          249          262            1
# 20611           3.20        1.0          141          146            1
# 20612           1.12        1.0          179            7            2
#
#        total_amount transaction_date  transaction_year  transaction_month  \
# 605           26.62       2024-12-31              2024                 12
# 687           15.70       2024-12-31              2024                 12
# 688           24.10       2024-12-31              2024                 12
# 861           23.88       2024-12-31              2024                 12
# 1108          10.40       2024-12-31              2024                 12
# 1312          47.40       2024-12-31              2024                 12
# 2276          20.52       2024-12-31              2024                 12
# 3941          18.00       2024-12-31              2024                 12
# 3942          14.03       2024-12-31              2024                 12
# 4324          69.30       2024-12-31              2024                 12
# 4370          34.97       2024-12-31              2024                 12
# 4654           7.95       2024-12-31              2024                 12
# 4655          92.50       2024-12-31              2024                 12
# 5217          15.90       2024-12-31              2024                 12
# 5335          21.30       2024-12-31              2024                 12
# 7623          17.16       2024-12-31              2024                 12
# 7624          39.84       2024-12-31              2024                 12
# 7625          23.30       2024-12-31              2024                 12
# 17542         32.30       2024-12-31              2024                 12
# 20611         23.60       2024-12-31              2024                 12
# 20612         10.40       2024-12-31              2024                 12
#
#        transaction_day  transaction_hour
# 605                 31                23
# 687                 31                23
# 688                 31                23
# 861                 31                23
# 1108                31                23
# 1312                31                23
# 2276                31                23
# 3941                31                23
# 3942                31                23
# 4324                31                23
# 4370                31                23
# 4654                31                23
# 4655                31                23
# 5217                31                23
# 5335                31                23
# 7623                31                20
# 7624                31                20
# 7625                31                21
# 17542               31                20
# 20611               31                21
# 20612               31                21

# %%
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_year']==2025]
(taxi_data_prepared['transaction_year']!=2025).sum()
# Out:
# 0

# %%
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_month']==1]
(taxi_data_prepared['transaction_month']!=1).sum()
# Out:
# 0

# %%
taxi_data_prepared.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'payment_type', 'total_amount', 'transaction_date',
#        'transaction_year', 'transaction_month', 'transaction_day',
#        'transaction_hour'],
#       dtype='object')

# %% [markdown]
# ### 4.4 - Aggergating Data by Time and Region

# %%
categorical_columns = ['PULocationID', 'transaction_date', 'transaction_month', 'transaction_day',
       'transaction_hour']
numerical_columns = ['trip_distance', 'total_amount']
all_needed_columns = categorical_columns + numerical_columns

# %%
main_taxi_df = taxi_data_prepared[all_needed_columns]
print(main_taxi_df.shape)
main_taxi_df.head()
# Out:
# (2873527, 7)
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0          229       2025-01-01                  1                1
# 1          236       2025-01-01                  1                1
# 2          141       2025-01-01                  1                1
# 3          244       2025-01-01                  1                1
# 4          244       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount
# 0                 0           1.60         18.00
# 1                 0           0.50         12.12
# 2                 0           0.60         12.10
# 3                 0           0.52          9.70
# 4                 0           0.66          8.30

# %%
taxi_grouped_by_region = main_taxi_df.groupby(categorical_columns).mean().reset_index() 
taxi_grouped_by_region['count_of_transactions'] = main_taxi_df.groupby(categorical_columns).count().reset_index()['total_amount']

# %%
print(taxi_grouped_by_region.shape)
taxi_grouped_by_region.head()
# Out:
# (75880, 8)
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2025-01-01                  1                1
# 1            1       2025-01-01                  1                1
# 2            1       2025-01-01                  1                1
# 3            1       2025-01-01                  1                1
# 4            1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2

# %% [markdown]
# ## 5. Benchmark Model

# %% [markdown]
# ### 5.1 - Setting Up Inputs for the Benchmark Model

# %%
data_for_benchmark_model = taxi_grouped_by_region.copy()
data_for_benchmark_model.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2025-01-01                  1                1
# 1            1       2025-01-01                  1                1
# 2            1       2025-01-01                  1                1
# 3            1       2025-01-01                  1                1
# 4            1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2

# %%
# Dropped the transcation_date
categorical_features_benchmark = ['PULocationID', 'transaction_month', 'transaction_day', 'transaction_hour']

# input_features_benchmark contains all the features used to train the model
input_features_benchmark  = categorical_features_benchmark + ['trip_distance']

# target_feature_benchmark is the value the model will try to predict
target_features_benchmark = 'total_amount'

# %% [markdown]
# ### 5.2 - Train-Test Split

# %%
# Import library to train and test model
from sklearn.model_selection import train_test_split

X_bench = data_for_benchmark_model[input_features_benchmark]
y_bench = data_for_benchmark_model[target_features_benchmark]

# one-hot encoding
X_bench = pd.get_dummies(X_bench)

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X_bench, y_bench, test_size = 0.33, random_state = 42)

# %%
print("X_train shape:", X_train_b.shape)
print("X_test shape:", X_test_b.shape)
print("y_train shape:", y_train_b.shape)
print("y_test shape:", y_test_b.shape)
# Out:
# X_train shape: (50839, 260)
# X_test shape: (25041, 260)
# y_train shape: (50839,)
# y_test shape: (25041,)

# %%
train_rows = set(X_train_b.index)
test_rows = set(X_test_b.index)
overlap = train_rows.intersection(test_rows)

print("Overlap:", len(overlap))
# Out:
# Overlap: 0

# %% [markdown]
# ### 5.3 - Fit a Model to the Data

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor(max_depth=10)
tree.fit(X_train_b, y_train_b)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %% [markdown]
# ### 5.4 - Model Evaluation

# %%
model_at_hand = tree

y_pred_b = model_at_hand.predict(X_test_b)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('Mean Absolute Error: ', mean_absolute_error(y_test_b, y_pred_b))
print('Mean Squared Error: ', mean_squared_error(y_test_b, y_pred_b))
print('Root Mean Squared Error: ', sqrt(mean_squared_error(y_test_b, y_pred_b)))
print('R2: ', r2_score(y_test_b, y_pred_b))
# Out:
# Mean Absolute Error:  6.726117947749941
# Mean Squared Error:  183.93353097473135
# Root Mean Squared Error:  13.562209664163555
# R2:  0.5737014637183375

# %%
data = {'true':y_test_b, 'pred':y_pred_b}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter',color='pink', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %% [markdown]
# ### 5.5 - Fixing Problem

# %%
categorical_features_benchmark = ['PULocationID', 'transaction_month', 'transaction_day', 'transaction_hour']

# input_features_benchmark contains all the features used to train the model without the trip distance
input_features_benchmark  = categorical_features_benchmark
target_feature_benchmark = 'total_amount'

X_bench = data_for_benchmark_model[input_features_benchmark]
y_bench = data_for_benchmark_model[target_feature_benchmark]

X_Bench = pd.get_dummies(X_bench)

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X_bench, y_bench, test_size=0.33, random_state=42)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('Mean Absolute Error: ', mean_absolute_error(y_test_b, y_pred_b))
print('Mean Squared Error: ', mean_squared_error(y_test_b, y_pred_b))
print('Root Mean Squared Error: ', sqrt(mean_squared_error(y_test_b, y_pred_b)))
print('R2: ', r2_score(y_test_b, y_pred_b))
# Out:
# Mean Absolute Error:  6.726117947749941
# Mean Squared Error:  183.93353097473135
# Root Mean Squared Error:  13.562209664163555
# R2:  0.5737014637183375

# %% [markdown]
# ### 6 - Feature Engineering

# %%
taxi_grouped_by_region.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2025-01-01                  1                1
# 1            1       2025-01-01                  1                1
# 2            1       2025-01-01                  1                1
# 3            1       2025-01-01                  1                1
# 4            1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2

# %%
# Copy original grouped data for safe feature engineering
data_with_new_features = taxi_grouped_by_region.copy()

# %%
data_with_new_features['transaction_week_day'] = data_with_new_features['transaction_date'].dt.weekday
data_with_new_features['weekend'] = data_with_new_features['transaction_week_day'].apply(lambda x: True if x==5 or x==6 else False)

# %% [markdown]
# #### 6.1 - Weekend and holiday feature engineering

# %%
# Add federal holiday feature using pandas time series tools
from pandas.tseries.holiday import USFederalHolidayCalendar

cal = USFederalHolidayCalendar()
holidays = pd.to_datetime(cal.holidays(start='2018', end='2025'))
data_with_new_features['is_holiday'] = data_with_new_features['transaction_date'].isin(holidays)

# %%
data_with_new_features.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2025-01-01                  1                1
# 1            1       2025-01-01                  1                1
# 2            1       2025-01-01                  1                1
# 3            1       2025-01-01                  1                1
# 4            1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2
#
#    transaction_week_day  weekend  is_holiday
# 0                     2    False        True
# 1                     2    False        True
# 2                     2    False        True
# 3                     2    False        True
# 4                     2    False        True

# %%
# Load and prepare zone lookup table
zone_lookup = pd.read_csv('data/taxi_zone_lookup.csv')
zone_lookup = zone_lookup[['LocationID', 'Borough']]
zone_lookup.head()
# Out:
#    LocationID        Borough
# 0           1            EWR
# 1           2         Queens
# 2           3          Bronx
# 3           4      Manhattan
# 4           5  Staten Island

# %%
# Load and prepare zone lookup table
data_with_new_features['PULocationID'] = data_with_new_features['PULocationID'].astype(int)

# Now merge
data_with_new_features = data_with_new_features.merge(
    zone_lookup, left_on='PULocationID', right_on='LocationID', how='left'
)

# Drop the extra 'LocationID' column if needed
data_with_new_features.drop('LocationID', axis=1, inplace=True)

# Check result
data_with_new_features.head()
# Out:
#    PULocationID transaction_date  transaction_month  transaction_day  \
# 0             1       2025-01-01                  1                1
# 1             1       2025-01-01                  1                1
# 2             1       2025-01-01                  1                1
# 3             1       2025-01-01                  1                1
# 4             1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2
#
#    transaction_week_day  weekend  is_holiday Borough
# 0                     2    False        True     EWR
# 1                     2    False        True     EWR
# 2                     2    False        True     EWR
# 3                     2    False        True     EWR
# 4                     2    False        True     EWR

# %%
# Quick check of distribution across boroughs
data_with_new_features['Borough'].value_counts()
# Out:
# Borough
# Manhattan        41416
# Brooklyn         14112
# Queens           13682
# Bronx             5128
# Unknown            685
# EWR                230
# Staten Island       83
# Name: count, dtype: int64

# %% [markdown]
# #### 6.2 - Weather data integration

# %%
# Load NYC weather data for January 2025
nyc_weather = pd.read_csv('data/New York, NY-weather -2025-01-01 to 2025-01-31.csv')
nyc_weather.head()
# Out:
#                           name             datetime  temp  feelslike   dew  \
# 0  New York, NY, United States  2025-01-01T00:00:00  46.2       41.6  42.8
# 1  New York, NY, United States  2025-01-01T01:00:00  45.6       45.6  42.9
# 2  New York, NY, United States  2025-01-01T02:00:00  45.4       43.9  42.9
# 3  New York, NY, United States  2025-01-01T03:00:00  45.3       45.3  42.5
# 4  New York, NY, United States  2025-01-01T04:00:00  46.7       45.6  43.6
#
#    humidity  precip  precipprob preciptype  snow  ...  sealevelpressure  \
# 0     87.86   0.000           0        NaN   0.0  ...             998.7
# 1     90.26   0.036         100       rain   0.0  ...             998.2
# 2     90.76   0.000           0        NaN   0.0  ...             997.9
# 3     89.75   0.000           0        NaN   0.0  ...             998.2
# 4     89.01   0.000           0        NaN   0.0  ...             997.9
#
#    cloudcover  visibility  solarradiation  solarenergy  uvindex  severerisk  \
# 0        98.1         8.8               0          0.0        0         NaN
# 1       100.0         7.3               0          0.0        0         NaN
# 2       100.0         6.6               0          0.0        0         NaN
# 3        93.1         5.5               0          0.0        0         NaN
# 4       100.0         6.2               0          0.0        0         NaN
#
#        conditions    icon                                           stations
# 0        Overcast  cloudy  72505394728,KEWR,KLGA,72502014734,F1417,KNYC,7...
# 1  Rain, Overcast    rain  72505394728,KEWR,KLGA,72502014734,F1417,KNYC,7...
# 2        Overcast  cloudy  72505394728,KEWR,KLGA,72502014734,F1417,KNYC,7...
# 3        Overcast  cloudy  72505394728,KEWR,KLGA,72502014734,F1417,KNYC,7...
# 4        Overcast  cloudy  72505394728,KEWR,KLGA,72502014734,F1417,KNYC,7...
#
# [5 rows x 24 columns]

# %%
nyc_weather.shape
# Out:
# (744, 24)

# %%
nyc_weather.dtypes
# Out:
# name                 object
# datetime             object
# temp                float64
# feelslike           float64
# dew                 float64
# humidity            float64
# precip              float64
# precipprob            int64
# preciptype           object
# snow                float64
# snowdepth           float64
# windgust            float64
# windspeed           float64
# winddir               int64
# sealevelpressure    float64
# cloudcover          float64
# visibility          float64
# solarradiation        int64
# solarenergy         float64
# uvindex               int64
# severerisk          float64
# conditions           object
# icon                 object
# stations             object
# dtype: object

# %%
nyc_weather.describe()
# Out:
#              temp   feelslike         dew    humidity      precip  precipprob  \
# count  744.000000  744.000000  744.000000  744.000000  744.000000  744.000000
# mean    31.719355   24.021909   13.943414   48.902863    0.000780    4.166667
# std      7.877785   10.223781   10.452104   14.210621    0.004871   19.996074
# min     11.300000   -3.000000   -7.200000   21.100000    0.000000    0.000000
# 25%     27.000000   17.300000    6.900000   39.435000    0.000000    0.000000
# 50%     31.300000   23.300000   13.050000   45.400000    0.000000    0.000000
# 75%     37.800000   31.800000   19.600000   54.310000    0.000000    0.000000
# max     51.900000   51.900000   43.800000   90.760000    0.059000  100.000000
#
#              snow   snowdepth    windgust   windspeed     winddir  \
# count  744.000000  744.000000  744.000000  744.000000  744.000000
# mean     0.001008    0.074772   20.129167    9.939651  264.848118
# std      0.016413    0.349039    9.763519    4.703027   63.824771
# min      0.000000    0.000000    2.500000    0.000000    0.000000
# 25%      0.000000    0.000000   11.200000    6.700000  250.000000
# 50%      0.000000    0.000000   20.800000    9.350000  281.000000
# 75%      0.000000    0.000000   28.250000   13.025000  302.000000
# max      0.430000    2.610000   42.600000   25.900000  360.000000
#
#        sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# count        744.000000  744.000000  744.000000      744.000000   744.000000
# mean        1014.597849   48.074462    9.490860       91.345430     0.327554
# std            8.588972   35.971415    1.488691      162.143666     0.583839
# min          996.000000    0.000000    0.600000        0.000000     0.000000
# 25%         1008.500000   14.100000    9.900000        0.000000     0.000000
# 50%         1014.500000   34.200000    9.900000        0.000000     0.000000
# 75%         1019.825000   89.500000    9.900000      104.500000     0.400000
# max         1036.100000  100.000000    9.900000      659.000000     2.400000
#
#           uvindex  severerisk
# count  744.000000         0.0
# mean     0.905914         NaN
# std      1.628074         NaN
# min      0.000000         NaN
# 25%      0.000000         NaN
# 50%      0.000000         NaN
# 75%      1.000000         NaN
# max      7.000000         NaN

# %% [markdown]
# #### 6.3 - Weather Data Cleaning

# %%
nyc_weather = nyc_weather.drop(columns=['name','icon','stations','dew','sealevelpressure','precipprob','severerisk','solarradiation','solarenergy','uvindex'])

# %%
nyc_weather.columns
# Out:
# Index(['datetime', 'temp', 'feelslike', 'humidity', 'precip', 'preciptype',
#        'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir', 'cloudcover',
#        'visibility', 'conditions'],
#       dtype='object')

# %%
nyc_weather.isna().sum()
# Out:
# datetime        0
# temp            0
# feelslike       0
# humidity        0
# precip          0
# preciptype    708
# snow            0
# snowdepth       0
# windgust        0
# windspeed       0
# winddir         0
# cloudcover      0
# visibility      0
# conditions      0
# dtype: int64

# %%
nyc_weather['preciptype'].value_counts()
# Out:
# preciptype
# rain,snow    19
# rain         16
# snow          1
# Name: count, dtype: int64

# %%
nyc_weather = nyc_weather.drop(columns=['preciptype'])

# %%
nyc_weather.isna().sum()
# Out:
# datetime      0
# temp          0
# feelslike     0
# humidity      0
# precip        0
# snow          0
# snowdepth     0
# windgust      0
# windspeed     0
# winddir       0
# cloudcover    0
# visibility    0
# conditions    0
# dtype: int64

# %%
for col in nyc_weather.columns:
    print(f'\nValue Count for Columns: {col}')
    print(nyc_weather[col].value_counts(),'\n\n')
# Out:
# Value Count for Columns: datetime
# datetime
# 2025-01-01T00:00:00    1
# 2025-01-21T19:00:00    1
# 2025-01-21T10:00:00    1
# 2025-01-21T11:00:00    1
# 2025-01-21T12:00:00    1
#                       ..
# 2025-01-11T10:00:00    1
# 2025-01-11T11:00:00    1
# 2025-01-11T12:00:00    1
# 2025-01-11T13:00:00    1
# 2025-01-31T23:00:00    1
# Name: count, Length: 744, dtype: int64
#
#
#
# Value Count for Columns: temp
# temp
# 28.5    20
# 27.4    12
# 28.3    11
# 36.2    11
# 31.1    10
#         ..
# 46.1     1
# 27.1     1
# 31.2     1
# 37.2     1
# 47.3     1
# Name: count, Length: 253, dtype: int64
#
#
#
# Value Count for Columns: feelslike
# feelslike
# 22.4    10
# 23.3     8
# 18.4     7
# 33.6     6
# 33.0     6
#         ..
# 16.5     1
# 19.4     1
# 39.0     1
# 38.0     1
# 43.3     1
# Name: count, Length: 341, dtype: int64
#
#
#
# Value Count for Columns: humidity
# humidity
# 43.72    4
# 46.45    3
# 54.64    3
# 42.17    3
# 43.24    3
#         ..
# 66.99    1
# 61.11    1
# 57.47    1
# 55.37    1
# 87.77    1
# Name: count, Length: 663, dtype: int64
#
#
#
# Value Count for Columns: precip
# precip
# 0.000    713
# 0.003      4
# 0.011      3
# 0.013      2
# 0.010      2
# 0.032      2
# 0.024      2
# 0.002      2
# 0.021      2
# 0.059      1
# 0.019      1
# 0.046      1
# 0.017      1
# 0.004      1
# 0.058      1
# 0.014      1
# 0.036      1
# 0.007      1
# 0.028      1
# 0.012      1
# 0.031      1
# Name: count, dtype: int64
#
#
#
# Value Count for Columns: snow
# snow
# 0.00    736
# 0.04      6
# 0.08      1
# 0.43      1
# Name: count, dtype: int64
#
#
#
# Value Count for Columns: snowdepth
# snowdepth
# 0.00    708
# 1.18     22
# 1.97      8
# 2.44      4
# 1.54      1
# 2.61      1
# Name: count, dtype: int64
#
#
#
# Value Count for Columns: windgust
# windgust
# 23.0    17
# 18.3    17
# 21.9    15
# 20.8    14
# 19.7    14
#         ..
# 35.0     1
# 32.1     1
# 34.2     1
# 39.4     1
# 8.7      1
# Name: count, Length: 230, dtype: int64
#
#
#
# Value Count for Columns: windspeed
# windspeed
# 8.1     15
# 7.5     14
# 9.3     11
# 10.5    10
# 7.4     10
#         ..
# 6.0      1
# 25.9     1
# 19.5     1
# 2.9      1
# 21.0     1
# Name: count, Length: 191, dtype: int64
#
#
#
# Value Count for Columns: winddir
# winddir
# 302    24
# 288    20
# 292    19
# 304    16
# 290    16
#        ..
# 25      1
# 35      1
# 26      1
# 323     1
# 15      1
# Name: count, Length: 181, dtype: int64
#
#
#
# Value Count for Columns: cloudcover
# cloudcover
# 10.5     106
# 100.0     70
# 34.2      56
# 95.7      49
# 19.2      37
#         ...
# 24.3       1
# 87.6       1
# 27.3       1
# 44.6       1
# 69.2       1
# Name: count, Length: 85, dtype: int64
#
#
#
# Value Count for Columns: visibility
# visibility
# 9.9    666
# 8.9      4
# 9.2      3
# 8.0      3
# 9.0      3
# 9.7      3
# 9.6      3
# 1.0      3
# 4.3      3
# 5.7      2
# 2.1      2
# 2.8      2
# 3.2      2
# 4.7      2
# 5.2      2
# 6.4      2
# 6.9      2
# 0.9      2
# 6.6      2
# 5.5      2
# 7.4      2
# 6.2      2
# 6.5      1
# 8.6      1
# 7.8      1
# 0.6      1
# 2.0      1
# 8.1      1
# 3.9      1
# 5.0      1
# 3.5      1
# 3.3      1
# 6.0      1
# 8.8      1
# 4.5      1
# 3.7      1
# 4.1      1
# 3.6      1
# 7.3      1
# 7.2      1
# 9.4      1
# 6.7      1
# 8.5      1
# 1.7      1
# 1.9      1
# 7.7      1
# 9.8      1
# 8.2      1
# 4.2      1
# Name: count, dtype: int64
#
#
#
# Value Count for Columns: conditions
# conditions
# Partially cloudy          312
# Clear                     250
# Overcast                  151
# Rain, Overcast             15
# Snow, Rain, Overcast       15
# Rain, Partially cloudy      1
# Name: count, dtype: int64

# %%
nyc_weather.dtypes
# Out:
# datetime       object
# temp          float64
# feelslike     float64
# humidity      float64
# precip        float64
# snow          float64
# snowdepth     float64
# windgust      float64
# windspeed     float64
# winddir         int64
# cloudcover    float64
# visibility    float64
# conditions     object
# dtype: object

# %%
nyc_weather['conditions'].value_counts()
# Out:
# conditions
# Partially cloudy          312
# Clear                     250
# Overcast                  151
# Rain, Overcast             15
# Snow, Rain, Overcast       15
# Rain, Partially cloudy      1
# Name: count, dtype: int64

# %%
print(nyc_weather['datetime'].dtype)
# Out:
# object

# %%
# Change datatime type 
nyc_weather['datetime'] = pd.to_datetime(nyc_weather['datetime'])

# %%
print(nyc_weather['datetime'].dtype)
# Out:
# datetime64[ns]

# %%
#Splitting hour month and day
nyc_weather['hour'] = nyc_weather['datetime'].dt.hour
nyc_weather['month'] = nyc_weather['datetime'].dt.month
nyc_weather['day'] = nyc_weather['datetime'].dt.day

# %%
# One Hot encoding

nyc_weather_encoded = pd.get_dummies(nyc_weather, columns = ['conditions'])

# %%
nyc_weather_encoded.columns
# Out:
# Index(['datetime', 'temp', 'feelslike', 'humidity', 'precip', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'cloudcover',
#        'visibility', 'hour', 'month', 'day', 'conditions_Clear',
#        'conditions_Overcast', 'conditions_Partially cloudy',
#        'conditions_Rain, Overcast', 'conditions_Rain, Partially cloudy',
#        'conditions_Snow, Rain, Overcast'],
#       dtype='object')

# %%
nyc_weather_encoded.dtypes
# Out:
# datetime                             datetime64[ns]
# temp                                        float64
# feelslike                                   float64
# humidity                                    float64
# precip                                      float64
# snow                                        float64
# snowdepth                                   float64
# windgust                                    float64
# windspeed                                   float64
# winddir                                       int64
# cloudcover                                  float64
# visibility                                  float64
# hour                                          int32
# month                                         int32
# day                                           int32
# conditions_Clear                               bool
# conditions_Overcast                            bool
# conditions_Partially cloudy                    bool
# conditions_Rain, Overcast                      bool
# conditions_Rain, Partially cloudy              bool
# conditions_Snow, Rain, Overcast                bool
# dtype: object

# %% [markdown]
# #### 6.4 - Merging datasets

# %%
data_with_new_features.head()
# Out:
#    PULocationID transaction_date  transaction_month  transaction_day  \
# 0             1       2025-01-01                  1                1
# 1             1       2025-01-01                  1                1
# 2             1       2025-01-01                  1                1
# 3             1       2025-01-01                  1                1
# 4             1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2
#
#    transaction_week_day  weekend  is_holiday Borough
# 0                     2    False        True     EWR
# 1                     2    False        True     EWR
# 2                     2    False        True     EWR
# 3                     2    False        True     EWR
# 4                     2    False        True     EWR

# %%
nyc_taxi_with_weather = data_with_new_features.merge(nyc_weather_encoded, left_on = ['transaction_month', 'transaction_day', 'transaction_hour'], right_on = ['month', 'day', 'hour'], how = 'left')

print(nyc_taxi_with_weather.shape)
# Out:
# (75880, 33)

# %%
nyc_taxi_with_weather.head()
# Out:
#    PULocationID transaction_date  transaction_month  transaction_day  \
# 0             1       2025-01-01                  1                1
# 1             1       2025-01-01                  1                1
# 2             1       2025-01-01                  1                1
# 3             1       2025-01-01                  1                1
# 4             1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2
#
#    transaction_week_day  weekend  ...  visibility hour month  day  \
# 0                     2    False  ...         7.4    6     1    1
# 1                     2    False  ...         9.8    9     1    1
# 2                     2    False  ...         9.9   12     1    1
# 3                     2    False  ...         9.9   13     1    1
# 4                     2    False  ...         9.9   14     1    1
#
#    conditions_Clear  conditions_Overcast  conditions_Partially cloudy  \
# 0             False                 True                        False
# 1             False                False                         True
# 2             False                 True                        False
# 3             False                 True                        False
# 4             False                 True                        False
#
#    conditions_Rain, Overcast  conditions_Rain, Partially cloudy  \
# 0                      False                              False
# 1                      False                              False
# 2                      False                              False
# 3                      False                              False
# 4                      False                              False
#
#    conditions_Snow, Rain, Overcast
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
# [5 rows x 33 columns]

# %%
nyc_taxi_with_weather = nyc_taxi_with_weather.drop(['datetime', 'hour', 'day', 'month'], axis=1)

# %%
nyc_taxi_with_weather.head()
# Out:
#    PULocationID transaction_date  transaction_month  transaction_day  \
# 0             1       2025-01-01                  1                1
# 1             1       2025-01-01                  1                1
# 2             1       2025-01-01                  1                1
# 3             1       2025-01-01                  1                1
# 4             1       2025-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 6       0.100000       115.000                      1
# 1                 9       0.000000       132.510                      4
# 2                12       0.000000       106.200                      2
# 3                13       1.333333        56.400                      3
# 4                14       2.160000        70.205                      2
#
#    transaction_week_day  weekend  ...  windspeed winddir  cloudcover  \
# 0                     2    False  ...        9.4     246        97.5
# 1                     2    False  ...        8.4     252        88.8
# 2                     2    False  ...       12.7     276        95.7
# 3                     2    False  ...       14.4     268        95.7
# 4                     2    False  ...       14.8     262        95.7
#
#    visibility  conditions_Clear  conditions_Overcast  \
# 0         7.4             False                 True
# 1         9.8             False                False
# 2         9.9             False                 True
# 3         9.9             False                 True
# 4         9.9             False                 True
#
#    conditions_Partially cloudy  conditions_Rain, Overcast  \
# 0                        False                      False
# 1                         True                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    conditions_Rain, Partially cloudy  conditions_Snow, Rain, Overcast
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
# [5 rows x 29 columns]

# %%
nyc_taxi_with_weather.isna().sum()
# Out:
# PULocationID                           0
# transaction_date                       0
# transaction_month                      0
# transaction_day                        0
# transaction_hour                       0
# trip_distance                          0
# total_amount                           0
# count_of_transactions                  0
# transaction_week_day                   0
# weekend                                0
# is_holiday                             0
# Borough                              544
# temp                                   0
# feelslike                              0
# humidity                               0
# precip                                 0
# snow                                   0
# snowdepth                              0
# windgust                               0
# windspeed                              0
# winddir                                0
# cloudcover                             0
# visibility                             0
# conditions_Clear                       0
# conditions_Overcast                    0
# conditions_Partially cloudy            0
# conditions_Rain, Overcast              0
# conditions_Rain, Partially cloudy      0
# conditions_Snow, Rain, Overcast        0
# dtype: int64

# %%
nyc_taxi_with_weather = nyc_taxi_with_weather.dropna(subset=['Borough'])

# %%
nyc_taxi_with_weather.isna().sum()
# Out:
# PULocationID                         0
# transaction_date                     0
# transaction_month                    0
# transaction_day                      0
# transaction_hour                     0
# trip_distance                        0
# total_amount                         0
# count_of_transactions                0
# transaction_week_day                 0
# weekend                              0
# is_holiday                           0
# Borough                              0
# temp                                 0
# feelslike                            0
# humidity                             0
# precip                               0
# snow                                 0
# snowdepth                            0
# windgust                             0
# windspeed                            0
# winddir                              0
# cloudcover                           0
# visibility                           0
# conditions_Clear                     0
# conditions_Overcast                  0
# conditions_Partially cloudy          0
# conditions_Rain, Overcast            0
# conditions_Rain, Partially cloudy    0
# conditions_Snow, Rain, Overcast      0
# dtype: int64

# %% [markdown]
# ### 7 - Model Training

# %% [markdown]
# #### 7.1 - Organizing Categorical, Input and Target

# %%
data_for_model = nyc_taxi_with_weather.copy()

# %%
categorical_features = ['PULocationID', 'transaction_month', 'transaction_day', 'transaction_hour', 'transaction_week_day', 
                        'weekend', 'is_holiday', 'Borough']

input_features = categorical_features + ['temp', 'humidity', 'precip', 'snow', 'snowdepth', 'windspeed', 'cloudcover', 'visibility']

target_features = 'total_amount'

# %% [markdown]
# #### 7.2 - Train-test split

# %%
from sklearn.model_selection import train_test_split

X = data_for_model[input_features]
y = data_for_model[target_features]

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree = DecisionTreeRegressor(max_depth=10)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
model_at_hand = decision_tree

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', sqrt(mean_squared_error(y_test, y_pred)))
print('r2: ', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  9.481558009000247
# Mean Squared Error:  251.0680191739394
# Root Mean Squared Error:  15.845126038436533
# r2:  0.36710094077251765

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter',color='pink', x='true', y='pred')
# Out:
# <Axes: xlabel='true', ylabel='pred'>

# %% [markdown]
# #### 7.3 - Overfit

# %%
X_train_overfit = X_train
y_train_overfit = y_train

X_test_overfit = X_test
y_test_overfit = y_test

# %%
rmse_scores = {'max_depth':[], 'rmse_train':[], 'rmse_test':[]}

for md in [2, 5, 8, 10, 15, 20, 30, 50, 70, 100, 150]:
    print(md)
    decision_tree_overfit = DecisionTreeRegressor(max_depth=md)
    decision_tree_overfit.fit(X_train_overfit, y_train_overfit)

    model_at_hand_overfit = decision_tree_overfit
    
    y_pred_train = model_at_hand_overfit.predict(X_train_overfit)
    rmse_train =sqrt(mean_squared_error(y_train_overfit, y_pred_train))
    
    y_pred_test = model_at_hand_overfit.predict(X_test_overfit)
    rmse_test = sqrt(mean_squared_error(y_test_overfit, y_pred_test))
    
    rmse_scores['max_depth'].append(md)
    rmse_scores['rmse_train'].append(rmse_train)
    rmse_scores['rmse_test'].append(rmse_test)
# Out:
# 2
# 5
# 8
# 10
# 15
# 20
# 30
# 50
# 70
# 100
# 150

# %%
ax = pd.DataFrame.from_dict(rmse_scores).plot(figsize=(10,5),title="rmse of training vs. testing datasets", fontsize=15, x='max_depth')
ax.set_xlabel("max depth", fontsize=15)
ax.set_ylabel("root mean squared error", fontsize=15)
# Out:
# Text(0, 0.5, 'root mean squared error')
